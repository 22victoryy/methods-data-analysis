# %%
## Simulation ##
set.seed(1002656486)
beta0 <- rnorm(n = 1, mean = 0, sd = 1) ## The population beta0 
beta1 <- runif(n = 1, min = 1, max = 3)  ## The population beta1
sig2 <- rchisq(n = 1, df = 1) ## The error variance sigma^2

## Multiple simulation may require loops ##
nsample <- 5  ## Sample size
n.sim <- 5 ## The number of simulations
sigX <- 0.2 ## The variances of X
## Simulate the predictor variable ##
X <- rnorm(n = nsample, mean = 0, sd = sqrt(sigX))


##########

### Simulate ##
b0 <- vector() ## saves the sample estimates of beta0
b1 <- vector() ## saves the sample estimates of beta1
sig2hat <- vector()  ## saves the sample estimates of sigma^2

meansb0 <- vector()
meansb1 <- vector()

sigy <- vector()  ## Saves the estimate of error variance













for(i in 1:n.sim){
    Y <- beta0 + beta1*X + rnorm(n = nsample, mean = 0, sd = sqrt(sig2))
    model <- lm(Y ~ X)
    b0[i] <- coef(model)[1]

    meansb0[i] = vcov(model)[2,2] # b0
    meansb1[i] = vcov(model)[1,2] # b0

    b1[i] <- coef(model)[2]
    sigy[i] <- summary(model)$sigma^2  # variance of each simulation.
    
    # sig2 is the true variance

    # print(summary(model))

    # sig2hat
    
    print(vcov(model))
#     print(summary(model))
}


# print(b0[1])
# mean(b0[1])
# var(b0[1])

# meansb0
# meansb1

# Y <- beta0 + beta1*X + rnorm(n = nsample, mean = 0, sd = sqrt(sig2))
# m <- lm(Y~X)
# sig2varb0 <- vcov(model)[2,2]
# print(sig2varb0)

sig2varb1 <- vcov(model)[1,2]
print(sig2varb1)




#
# print(0.8683^2)
# Out:
#             (Intercept)          X
# (Intercept)   0.3102370 -0.1760197
# X            -0.1760197  0.7538844
#             (Intercept)          X
# (Intercept)   0.3613780 -0.2050357
# X            -0.2050357  0.8781586
#             (Intercept)           X
# (Intercept)  0.09079928 -0.05151696
# X           -0.05151696  0.22064477
#             (Intercept)          X
# (Intercept)   0.5128158 -0.2909573
# X            -0.2909573  1.2461567
#             (Intercept)          X
# (Intercept)   0.2374531 -0.1347242
# X            -0.1347242  0.5770177
# [1] -0.1347242
